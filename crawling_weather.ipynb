# %%
import requests
from bs4 import BeautifulSoup
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 제주도

# %%
def crawl_weather_data(year, month, date, time) :
    address =f'https://www.weather.go.kr/w/obs-climate/land/city-obs.do?auto_man=m&stn=0&dtm=&type=t99&reg=184&tm={year}.{month}.{date}.{time}%3A00'
    source = requests.get(address)
    soup = BeautifulSoup(source.content, 'html.parser')
    
    div = soup.find('div',{'class':'over-scroll'})

    weather = []
    for table in div.find_all('table'):
        tbodys = list(table.find_all('tbody'))
        
        for tbody in tbodys :
            tds = list(tbody.find_all('td'))
            
            for td in tbody.find_all('td') :
                if td.find('a') :
                    weather_dic = {}
                    point = td.find('a').text
                    # print('point>>>>>>>',point)
                    current_temp = tds[5].text
                    # print('current_temp>>>>>>>',current_temp)
                    body_temp = tds[7].text
                    # print('body_temp>>>>>>',body_temp)
                    weather_dic['point'] = point 
                    weather_dic['cur_temp'] = current_temp
                    weather_dic['body_temp'] = body_temp     
                    weather.append(weather_dic) 
                    
    weather_df = pd.DataFrame(weather)
    
    return weather_df

# %%
crawl_weather_data('2019','09','01','10')
# Out:
#   point cur_temp body_temp
# 0    고산     25.1      27.0
# 1   서귀포     25.1      27.0
# 2    성산     25.1      27.0
# 3    제주     25.1      27.0

# %% [markdown]
# # 서울

# %%
def crawl_seoul_weather_data(address) :
    source = requests.get(address)
    soup = BeautifulSoup(source.content, 'html.parser')
    
    table = soup.find('table',{'border':'0'})
    
    weather_seoul = []
    for tr in table.find_all('tr') :
        tds = list(tr.find_all('td'))
        if len(tds) == 20 :
            point = tds[19].text
            # print('point >>>>>>',point)
            
            proto = []
            for td in tds :
                proto.append(td.text)
            
            weather_dic_seoul = {}
            weather_dic_seoul['point'] = proto[1]
            weather_dic_seoul['main_point'] = proto[19]
            weather_dic_seoul['temp'] = proto[10]
            weather_dic_seoul['rain'] = proto[3]
            weather_seoul.append(weather_dic_seoul)
            
        
    weather_seoul_df = pd.DataFrame(weather_seoul)       
    return weather_seoul_df

# %%
address = 'https://www.weather.go.kr/cgi-bin/aws/nph-aws_txt_min_cal_test?0&0&MINDB_01M&4108&a&M'
crawl_seoul_weather_data(address)
# Out:
#     point       main_point  temp rain
# 0      서울    서울특별시 종로구 송월동  24.7    ●
# 1      중구     서울특별시 중구 예장동  22.9    ○
# 2      용산    서울특별시 용산구 이촌동  24.9    ○
# 3      성동  서울특별시 성동구 성수동1가  25.2    ○
# 4      광진    서울특별시 광진구 자양동  24.1    ●
# 5     동대문   서울특별시 동대문구 전농동  24.4    ○
# 6      중랑    서울특별시 중랑구 면목동  24.8    ●
# 7      성북    서울특별시 성북구 정릉동  24.0    ●
# 8    강북 *    서울특별시 강북구 수유동  24.7    ●
# 9      도봉    서울특별시 도봉구 방학동  24.7    ●
# 10     노원    서울특별시 노원구 공릉동  23.9    ●
# 11     은평    서울특별시 은평구 진관동  23.6    ●
# 12    서대문   서울특별시 서대문구 신촌동  23.6    ●
# 13     마포    서울특별시 마포구 망원동  24.0    ●
# 14   양천 *     서울특별시 양천구 목동  24.4    ●
# 15     강서    서울특별시 강서구 화곡동  24.1    ●
# 16  김포(공)    서울특별시 강서구 공항동  24.0    -
# 17     구로     서울특별시 구로구 궁동  24.1    ●
# 18     금천    서울특별시 금천구 독산동  24.7    ○
# 19     한강  서울특별시 영등포구 여의도동  24.8    ●
# 20  영등포 *   서울특별시 영등포구 당산동  24.7    ●
# 21    현충원    서울특별시 동작구 사당동  25.2    ●
# 22    기상청   서울특별시 동작구 신대방동  23.7    ●
# 23     관악    서울특별시 관악구 신림동  23.7    ●
# 24     남현    서울특별시 관악구 남현동  24.1    ○
# 25     서초    서울특별시 서초구 서초동  24.7    ●
# 26     강남    서울특별시 강남구 일원동  24.8    ○
# 27   송파 *    서울특별시 송파구 잠실동  24.7    ●
# 28     강동    서울특별시 강동구 고덕동  24.6    ●
# 29     광명      경기도 광명시 철산동  24.5    ○
# 30   광명철산      경기도 광명시 철산동     .    -
# 31     소하      경기도 광명시 소하동  24.2    ○
# 32   광명노온     경기도 광명시 노온사동  23.6    ●
# 33    학온동      경기도 광명시 가학동  23.8    ○
# 34     과천      경기도 과천시 과천동  24.4    ●
# 35  관악(레)      경기도 과천시 중앙동  21.1    ●
